# %%
from fraud_preprocessing import *
from joblib import load

# %%
model=load('Credit_card_fraud_detection.joblib')

# %%
df=pd.read_csv("fraudTest.csv")
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
def preprocess(data):
    global X,y
    df=transform_data(data)
    df=encoding(df)
    df=drop_cols(df)
    X=df.drop('is_fraud',axis=1)
    y=df['is_fraud']
    X=scaling(X)
    return X,y

# %%
X,y=preprocess(df)

# %%
predictions=model.predict(X)

# %%
X.shape
# Out:
# (555719, 10)

# %%
scores(y,predictions)
# Out:
# Random Forest
# Accuracy Score: 0.9824785548091751
#
# Precision Score: 0.17225004317043688
#
# Recall Score: 0.9300699300699301
#
# F1 Score: 0.2906680265170831
#
# Confusion Matrix:
#  [[543987   9587]
#  [   150   1995]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    553574
#            1       0.17      0.93      0.29      2145
#
#     accuracy                           0.98    555719
#    macro avg       0.59      0.96      0.64    555719
# weighted avg       1.00      0.98      0.99    555719
