# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Check the version of pandas to ensure it is installed correctly
print(pd.__version__)
# Out:
# 2.2.2

# %%
import pandas as pd

# %%
df=pd.read_csv('fraudTest.csv')
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  int64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  555719.000000  5.557190e+05  555719.000000  555719.000000
# mean   277859.000000  4.178387e+17      69.392810   48842.628015
# std    160422.401459  1.309837e+18     156.745941   26855.283328
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%    138929.500000  1.800429e+14       9.630000   26292.000000
# 50%    277859.000000  3.521417e+15      47.290000   48174.000000
# 75%    416788.500000  4.635331e+15      83.010000   72011.000000
# max    555718.000000  4.992346e+18   22768.110000   99921.000000
#
#                  lat           long      city_pop     unix_time  \
# count  555719.000000  555719.000000  5.557190e+05  5.557190e+05
# mean       38.543253     -90.231325  8.822189e+04  1.380679e+09
# std         5.061336      13.721780  3.003909e+05  5.201104e+06
# min        20.027100    -165.672300  2.300000e+01  1.371817e+09
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns = "Unnamed: 0",inplace = True)

# %%
df.head(2)
# Out:
#   trans_date_trans_time            cc_num               merchant  \
# 0   2020-06-21 12:14:25  2291163933867244  fraud_Kirlin and Sons
# 1   2020-06-21 12:14:33  3573030041201292   fraud_Sporer-Keebler
#
#         category    amt   first      last gender             street      city  \
# 0  personal_care   2.86    Jeff   Elliott      M  351 Darlene Green  Columbia
# 1  personal_care  29.84  Joanne  Williams      F   3638 Marsh Union   Altonah
#
#    ...      lat      long  city_pop                     job         dob  \
# 0  ...  33.9659  -80.9355    333497     Mechanical engineer  1968-03-19
# 1  ...  40.3207 -110.4360       302  Sales professional, IT  1990-01-17
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  2da90c7d74bd46a0caf3777415b3ebd3  1371816865  33.986391  -81.200714
# 1  324cc204407e99f51b0d6ca0055005e7  1371816873  39.450498 -109.960431
#
#    is_fraud
# 0         0
# 1         0
#
# [2 rows x 22 columns]

# %%
df.is_fraud.value_counts()
# Out:
# is_fraud
# 0    553574
# 1      2145
# Name: count, dtype: int64

# %%
df.dob.dtype
# Out:
# dtype('O')

# %%
df.dob=pd.to_datetime(df.dob)

# %%
df.dob.dtype
# Out:
# dtype('<M8[ns]')

# %%
df['trans_date_trans_time']=pd.to_datetime(df['trans_date_trans_time'])

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (6,4))
labels = ["Not Fraud","Fraud"]
values = df.is_fraud.value_counts()
plt.pie(values,labels = labels,autopct = "%1.1f%%",startangle = 140)
plt.title("Distribution of Fraud")
plt.show()

# %%
df.reset_index(inplace=True)

# %%
fraud_job_title = df[df["is_fraud"] == 1]["job"].value_counts().head(10)
fraud_job_title
# Out:
# job
# Science writer                            30
# Licensed conveyancer                      29
# Systems developer                         29
# Engineer, biomedical                      28
# Therapist, occupational                   27
# Colour technologist                       27
# Counsellor                                26
# Comptroller                               26
# Research scientist (physical sciences)    25
# Commissioning editor                      24
# Name: count, dtype: int64

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ----- ---------------------------------- 41.0/294.9 kB 2.0 MB/s eta 0:00:01
#    ------------ --------------------------- 92.2/294.9 kB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 245.8/294.9 kB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
fraud_job_title_df = fraud_job_title.reset_index()
fraud_job_title_df.columns = ['job', 'count']

# Plotting
plt.figure(figsize=(6, 4))
sns.barplot(data=fraud_job_title_df, x="count", y="job",palette="plasma")
plt.title('Top 10 Job Titles Associated with Fraud')
plt.xlabel('Count')
plt.ylabel('Job Title')
plt.xticks()
plt.show()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_2932\115944590.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=fraud_job_title_df, x="count", y="job",palette="plasma")

# %%
df["category"].value_counts()
# Out:
# category
# gas_transport     56370
# grocery_pos       52553
# home              52345
# shopping_pos      49791
# kids_pets         48692
# shopping_net      41779
# entertainment     40104
# personal_care     39327
# food_dining       39268
# health_fitness    36674
# misc_pos          34574
# misc_net          27367
# grocery_net       19426
# travel            17449
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,6))
sns.countplot(x = "category",hue = "is_fraud",data = df,palette = "viridis")
plt.title("Category")
plt.xticks(rotation = 60)
plt.show()

# %%
plt.figure(figsize = (8,6))
fraud_category = df[df["is_fraud"] == 1]["category"].value_counts()
sns.barplot(x = fraud_category.index,y = fraud_category.values, palette = "viridis")
plt.title("Category vs Fraud")
plt.xticks(rotation = 60)
plt.show()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_2932\3789701378.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = fraud_category.index,y = fraud_category.values, palette = "viridis")

# %%
df["city"].value_counts()
# Out:
# city
# Birmingham     2423
# Meridian       2229
# Phoenix        2222
# Utica          2204
# San Antonio    2182
#                ...
# Senatobia        10
# Guthrie           9
# Seattle           9
# Rice              8
# Wever             6
# Name: count, Length: 849, dtype: int64

# %%
amt_99 = df['amt'].quantile(0.99)
plt.figure(figsize=(8,6))
sns.histplot(data=df[df['amt'] <= amt_99], x="amt", hue="is_fraud", multiple="stack", bins=50, palette="viridis")
plt.title('Distribution of Transaction Amounts (Up to 99th Percentile)')
plt.xlabel('Transaction Amount')
plt.ylabel('Count')
plt.show()

# %%
fraud_rate_by_state = df.groupby('state')['is_fraud'].mean().sort_values(ascending=False).reset_index().head(10)

plt.figure(figsize=(8,6))
sns.barplot(data=fraud_rate_by_state, x='is_fraud', y='state', palette='viridis')
plt.title('Fraud Rate by State')
plt.xlabel('Fraud Rate')
plt.ylabel('State');
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_2932\4068390508.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=fraud_rate_by_state, x='is_fraud', y='state', palette='viridis')

# %%
df.trans_date_trans_time.head()
# Out:
# 0   2020-06-21 12:14:25
# 1   2020-06-21 12:14:33
# 2   2020-06-21 12:14:53
# 3   2020-06-21 12:15:15
# 4   2020-06-21 12:15:17
# Name: trans_date_trans_time, dtype: datetime64[ns]

# %%
df.set_index('trans_date_trans_time', inplace=True)

# %%
plt.figure(figsize=(15, 8))
df.resample('D')['is_fraud'].sum().plot(label='Fraudulent Transactions', color='red')
df.resample('D')['is_fraud'].count().plot(label='Total Transactions', color='blue')
plt.title('Transactions Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df[df['is_fraud'] == 1], x='long', y='lat', hue='is_fraud', palette='viridis', legend=False)
plt.title('Fraudulent Transaction Locations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
